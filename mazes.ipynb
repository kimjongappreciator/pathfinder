# %%
from collections import deque
import queue
import sys
import numpy
sys.setrecursionlimit(2550)
    
class player:    
	x, y = 0, 0
	h = 0
	traps = 0
	goal = " "
	symbol = " "
	path = " "
	def __init__(self, x, y, goal, symbol):
		self.x = x
		self.y = y
		self.h = 0
		self.traps = 5
		self.goal = goal
		self.symbol = symbol
		self.path = " "

	def move(self, dir, table):
		
		if dir == 'u':
			self.y -= 1
			self.x += 0
		elif dir == 'd':
			
			self.y += 1
			self.x += 0
		elif dir == 'l':
			
			self.x -= 1 
			self.y += 0
		elif dir =='r':
			
			self.x += 1
			self.y += 0	
		
	def setpos(self, x, y):
		self.x = x
		self.y = y

	def seth(self,h):
		self.h = h

	def pos(self):
		return (self.x, self.y)
	
	def trapset(self):
		self.traps -= 1
 
	def printpos(self):
		print(self.x, self.y)
	
	def setpath(self, camino):
		self.path = camino

	def getpath(self):
		return self.path
 
  

class board:
	
	table = []
	play = 0
	
	def __init__(self):
		
		self.table = [["#"," ", "A", "A", "A", "A", "A", " ", "#"],
    				  [" "," ", " ", " ", " ", " ", " ", " ", " "],
    				  [" "," ", " ", " ", " ", " ", " ", " ", " "],
    				  [" "," ", " ", " ", " ", " ", " ", " ", " "],
   					  [" "," ", " ", " ", " ", " ", " ", " ", " "],
                      [" "," ", " ", " ", " ", " ", " ", " ", " "],
                      [" "," ", " ", " ", " ", " ", " ", " ", " "],
                      [" "," ", " ", " ", " ", " ", " ", " ", " "],
                      ["#"," ", "X", "X", "X", "X", "X", "", "#"]]
		self.play = 2
		
	def first(self):
		self.play -=1

	def update(self, player, player2):
		
		self.table[player.y][player.x] = player.symbol
		
		
		self.table[player2.y][player2.x] = player2.symbol
		
		
	
	def validmove(self, maze, player, moves):
		i = player.x
		j = player.y
		for move in moves:
			if move == 'l':
				i-=1
			elif move == 'r':
				i+=1
			elif move == 'u':
				j -=1
			elif move == 'd':
				j+=1
			if not (0 <= i < 9 and 0 <= j < 9):
				#print("movimiento ilegal")
				return False
			
			elif (maze[j][i]=="#"):
				#print("movimiento ilegal")
				return False
			
		return True
	 
	 		
	def bfs(self,maze,player, moves):
		j = player.y
		i = player.x
		for move in moves:
			if move == 'l':
				i-=1
			elif move == 'r':
				i+=1
			elif move == 'u':
				j -=1
			elif move == 'd':
				j+=1
		if (maze[j][i] == player.goal):
			print("found:" + moves)
			return True
		return False
	
	def findend(self, player): #este es el bfs
		nums = queue.Queue()
		nums.put(" ")   
		add = " "
		maze = self.table
		while not self.bfs(maze, player, add):
			add = nums.get() #sacas el primero del queue FIFO
			#print(add)
			for j in ["l", "r", "u", "d"]:
				put = add + j
				if self.validmove(maze, player, put):
					nums.put(put) #agregas al queue
		return add

	def moveto(self, player, x,y):
		self.table[y][x] = player.symbol
	
	
	def settrap(self, x, y):
		self.table[y][x] = "#"
 
	def clean(self, x, y):
		if x == 2 and y == 0 or x == 3 and y == 0 or x == 5 and y == 0  or x == 6 and y == 0:
			self.table[y][x] = "A"  
		elif x == 2 and y == 8 or x == 3 and y == 8 or x == 5 and y == 8  or x == 6 and y == 8:
			self.table[y][x] = "X"
		else:	
			self.table[y][x] = " "
	def printboard(self):
		for row in enumerate(self.table):
			 for col in enumerate(row):
				 print(col)

# %%
def DFSsolver(maze, destination, start, path=[], passed=[]):
    (x,y) = start 

    

    if (x,y) not in passed:
        path.append((x, y))
        passed.append((x, y))

    
    if (x,y) == destination:
        return path

    
    else:
        pointqueue = [(x - 1, y), (x, y - 1), (x + 1, y), (x, y + 1)]
        queue = []
        for point in pointqueue:
           
            if len(maze)-1 >= point[1] >= 0 and len(maze[0])-1 >= point[0] >= 0:
                
                if maze[point[1]][point[0]] == " " and point not in passed:
                    queue.append(point)

       
        if len(queue)!= 0:
            for point in queue:
                return DFSsolver(maze, destination, point, path)

       
        else:
            path.remove((x, y))
            return DFSsolver(maze, destination, path[-1], path)

# %%
def bruteforce(deck, player):
    cola = []
    maze = deck
    counter = 0
    j = player.y
    i = player.x
    

    while True:
        
        maze[i][j] = 1
        if maze[i][j+1] == "X":
            break
        elif maze[i][j-1] == "X":
            break
        elif maze[i+1][j] == "X":
            break
        elif maze[i-1][j] == "X":
            break
            
        elif maze[i][j+1] == " ":
            #print("d")
            cola.append("d")
            counter +=1
            j += 1
        elif maze[i][j-1] == " ":
            #print("u")
            cola.append("u")
            counter+=1
            j -=1
        elif maze[i+1][j] == " ":
            #print("r")
            cola.append("r")
            counter+=1
            i+=1
        elif maze[i-1][j] == " ":
            #print("l")
            cola.append("l")
            counter+=1
            i-=1
    
                 
    print(cola)
    return cola

# %%
def play1(player, board):
    posib = numpy.random.randint(1,5)
    rx = numpy.random.randint(1,8)
    ry = numpy.random.randint(1,8)
    if posib == 1:
        board.settrap(rx,ry)
        print("setting trap at:", rx, ry)
    else:
        xd = board.findend(player)
        board.clean(player.x, player.y)
        player.move(xd[1],tablita)

def play2(player, board):
    destination = (5, 5)
    x = player.x
    y = player.y
    start = (x,y)
    m = DFSsolver(board.table, destination, start)
    print(m)
    p = m[1]
    board.clean(player.x, player.y)
    player.setpos(p[0],p[1])
    board.moveto(player, player.x,player.y)

def play3(player, board):
    var = board.table
    xd = bruteforce(var, player)
    board.clean(player.x, player.y)
    player.move(xd[0],board)

# %%
jeff = player(5,0,"X","O")
bot = player(5,8,"A", "b")
tablita = board()

#tablita.settrap(3,6)
tablita.update(jeff,bot)
tablita.printboard()
print("----------------------------------------------------")
for i in range(8):
    tablita.update(jeff,bot)
    #nu = ["d", "r","r","d","d","d","d","d"]
    #tabla = tablita.table
    #tablita.validmove(tabla, jeff, nu)
    #xd = tablita.findend(jeff)
    #jeff.move(xd[1],tablita)
    play1(jeff, tablita)
    play1(bot,tablita)
    #tablita.moveto(jeff,4,1)
    tablita.update(jeff,bot)
    #tablita.settrap(4,1)
    tablita.printboard()
    print("----------------------------------------------------")
# Out:
# (0, 0)
# (1, ['#', '#', 'A', '#', '#', 'O', '#', '#', '#'])
# (0, 1)
# (1, ['#', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '#'])
# (0, 2)
# (1, ['#', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '#'])
# (0, 3)
# (1, ['#', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '#'])
# (0, 4)
# (1, ['#', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '#'])
# (0, 5)
# (1, ['#', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '#'])
# (0, 6)
# (1, ['#', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '#'])
# (0, 7)
# (1, ['#', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '#'])
# (0, 8)
# (1, ['#', '#', '#', '#', '#', 'b', '#', 'X', '#'])
# ----------------------------------------------------
# found: drrddddddd
# found: ullluuuuuuu
# (0, 0)
# (1, ['#', '#', 'A', '#', '#', ' ', '#', '#', '#'])
# (0, 1)
# (1, ['#', ' ', ' ', ' ', ' ', 'O', ' ', ' ', '#'])
# (0, 2)
# (1, ['#', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '#'])
# (0, 3)
# (1, ['#', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '#'])
# (0, 4)
# (1, ['#', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '#'])
# (0, 5)
# ...

# %%
#caso 2 corregir bug
table = board()
bot1 = player(5,0,"A", "b")
bot2 = player(5,8,"X","O") 
table.update(bot1, bot2)
table.printboard()
for i in range(10):
    play2(bot1, table)
    table.update(bot1, bot2)
    table.printboard()
# Out:
# (0, 0)
# (1, ['#', '#', 'A', '#', '#', 'b', '#', '#', '#'])
# (0, 1)
# (1, ['#', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '#'])
# (0, 2)
# (1, ['#', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '#'])
# (0, 3)
# (1, ['#', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '#'])
# (0, 4)
# (1, ['#', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '#'])
# (0, 5)
# (1, ['#', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '#'])
# (0, 6)
# (1, ['#', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '#'])
# (0, 7)
# (1, ['#', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '#'])
# (0, 8)
# (1, ['#', '#', '#', '#', '#', 'O', '#', 'X', '#'])
# [(5, 0), (5, 1), (4, 1), (3, 1), (2, 1), (1, 1), (1, 2), (2, 2), (3, 2), (4, 2), (5, 2), (6, 2), (6, 1), (7, 1), (7, 2), (7, 3), (6, 3), (5, 3), (4, 3), (3, 3), (2, 3), (1, 3), (1, 4), (2, 4), (3, 4), (4, 4), (5, 4), (6, 4), (7, 4), (7, 5), (6, 5), (5, 5)]
# (0, 0)
# (1, ['#', '#', 'A', '#', '#', ' ', '#', '#', '#'])
# (0, 1)
# (1, ['#', ' ', ' ', ' ', ' ', 'b', ' ', ' ', '#'])
# (0, 2)
# ...

# %%
#caso 3 bruteforcebacktrack corregir bugs
tabla = board()
bot3 = player(5,0,"A", "b")
bot4 = player(5,8,"X","O")
tabla.update(bot3, bot4)
tabla.printboard() 
play3(bot3, tabla)
# Out:
# (0, 0)
# (1, ['#', '#', 'A', '#', '#', 'b', '#', '#', '#'])
# (0, 1)
# (1, ['#', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '#'])
# (0, 2)
# (1, ['#', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '#'])
# (0, 3)
# (1, ['#', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '#'])
# (0, 4)
# (1, ['#', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '#'])
# (0, 5)
# (1, ['#', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '#'])
# (0, 6)
# (1, ['#', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '#'])
# (0, 7)
# (1, ['#', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '#'])
# (0, 8)
# (1, ['#', '#', '#', '#', '#', 'O', '#', 'X', '#'])
# ['d', 'd', 'd', 'd', 'd', 'd', 'd', 'r', 'u', 'u', 'u', 'u', 'u', 'u', 'r', 'd', 'd', 'd', 'd', 'd', 'd']
